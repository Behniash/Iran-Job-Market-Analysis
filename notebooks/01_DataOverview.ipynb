# %%
import pandas as pd
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))

# %%
df = pd.read_csv("../data/processed/jobs_clean.csv")
df
# Out:
#        keyword   job_id                                             title  \
# 0       python  1396130                                برنامه نویس Python
# 1       python  1401623  Senior Backend Engineer(Python/FastAPI)- Shoraka
# 2       python  1436012                                برنامه نویس Python
# 3       python  1390562                برنامه نویس بک‌اند (Python/Django)
# 4       python  1429358                                برنامه نویس Python
# ...        ...      ...                                               ...
# 12250  network  1393542                        منشی مطب دندانپزشکی - خانم
# 12251  network  1407062                                          روانشناس
# 12252  network  1450304                       منشی (کلینیک زیبایی) - خانم
# 12253  network  1401482                                              وکیل
# 12254  network  1433777                                منشی کلینیک - خانم
#
#                                      company province   city  salary_visible  \
# 0                                      بارکس    تهران  تهران           False
# 1                                 بیمه بازار    تهران  تهران           False
# 2                        ارتباطات فرهنگ آزما    تهران  تهران           False
# 3                      شرکت بیمۀ زندگی باران    تهران  تهران           False
# 4               شرکت پیشگامان توسعه ارتباطات    تهران  تهران           False
# ...                                      ...      ...    ...             ...
# 12250      مطب دندانپزشکی دکتر آرزو ساریخانی    تهران  تهران           False
# 12251  موسسه مرکز نوآوری و پژوهش سرای مارلیک    گیلان    رشت           False
# 12252                کلینیک زیبایی پوست و مو    تهران  تهران            True
# 12253     سازمانی فعال در حوزه حقوقی و قضایی    کرمان  کرمان           False
# 12254           کلینیک روانشناسی ساناز صفائی    تهران  تهران            True
#
#        experience_years                                        description  \
# 0                     5  ما برای توسعه ERP شرکت بر پایه Odoo به دنبال ی...
# 1                     3  We are looking for a Senior Backend Engineer t...
# 2                     2  ما در تیم تحقیق و توسعه فرهنگ آزما به دنبال یک...
# 3                     3  اگر توسعه‌دهنده‌ای هستید که چالش‌های فنی شما ر...
# 4                     2  نکات فنی: تسلط بر Django آشنایی با DRF آشنایی ...
# ...                 ...                                                ...
# 12250                 1  - خوش برخورد - دارای حداقل یکسال سابقه کاری - ...
# 12251                 4  مرکز نوآوری و پژوهش‌سرای دانش‌آموزی در گلسار ر...
# 12252                 3  کلینیک زیبایی ما جهت تکمیل کادر خود از منشی خا...
# 12253                 5  یک شرکت حقوقی فعال با قراردادهای جاری با ارگان...
# 12254                 0  شرح وظایف: پاسخگویی حرفه‌ای، محترمانه و همدلان...
#
#                     work_type  ... business_trip  \
# 0                   Full Time  ...           NaN
# 1                   Full Time  ...           NaN
# 2                   Full Time  ...           NaN
# 3                   Full Time  ...           NaN
# 4                   Full Time  ...           NaN
# ...                       ...  ...           ...
# 12250               Full Time  ...         ندارد
# 12251         Project - based  ...           NaN
# 12252               Full Time  ...           NaN
# 12253               Part Time  ...           NaN
# 12254  Full Time Or Part Time  ...           NaN
#
#                                                 software  \
# 0                             Python,Oracle Database,GIT
# 1      Python,PostgreSql,Prometheus,Gerafana,Docker,R...
# 2      Python,Django,GIT,MySql,PostgreSql,Redis,Linux...
# 3                                Python,Django,GIT,Linux
# 4                                Linux,Django,GIT,Python
# ...                                                  ...
# 12250                                                NaN
# 12251                                                NaN
# 12252                                                NaN
# 12253                                                NaN
# 12254                                                NaN
#
#                                          software_levels     first_activation  \
# 0                                   Advanced,Basic,Basic  2026-05-20 15:30:13
# 1      Advanced,Intermediate,Intermediate,Intermediat...                  NaN
# 2      Advanced,Advanced,Advanced,Intermediate,Interm...                  NaN
# 3                  Intermediate,Intermediate,Basic,Basic  2026-05-25 09:28:51
# 4        Intermediate,Advanced,Intermediate,Intermediate                  NaN
# ...                                                  ...                  ...
# 12250                                                NaN  2026-05-18 11:00:48
# 12251                                                NaN  2026-05-31 13:24:47
# 12252                                                NaN  2026-07-15 09:13:07
# 12253                                                NaN  2026-05-25 12:32:57
# 12254                                                NaN                  NaN
#
#                 activation               expire  application_count  \
# 0      2026-05-20 15:30:13  2026-07-19 15:30:13              495.0
# 1                      NaN                  NaN              805.0
# 2                      NaN                  NaN              354.0
# 3      2026-06-14 09:28:52  2026-07-24 09:28:51              882.0
# 4                      NaN                  NaN              587.0
# ...                    ...                  ...                ...
# 12250  2026-05-18 11:00:48  2026-07-17 11:00:48              884.0
# 12251  2026-05-31 13:24:47  2026-07-30 13:24:47               46.0
# 12252  2026-07-15 09:13:07  2026-09-13 09:13:07              108.0
# 12253  2026-05-25 12:32:57  2026-07-24 12:32:57               45.0
# 12254                  NaN                  NaN              326.0
#
#        internship remote  urgent
# 0           False  False    True
# 1           False   True    True
# 2           False  False   False
# 3           False  False    True
# 4           False  False   False
# ...           ...    ...     ...
# 12250       False  False   False
# 12251       False  False   False
# 12252       False  False   False
# 12253       False  False   False
# 12254       False  False   False
#
# [12255 rows x 33 columns]
